-- %%
create catalog my_sql;

-- %%
create schema my_sql.joins;

-- %%
use catalog my_sql;
use schema joins;

-- %%
CREATE TABLE Customers (
    customer_id INT PRIMARY KEY,
    customer_name VARCHAR(50),
    city VARCHAR(50)
);

-- %%
INSERT INTO Customers VALUES
(1,'Vijay','Chennai'),
(2,'Ravi','Bangalore'),
(3,'Sona','Hyderabad'),
(4,'Priya','Mumbai'),
(5,'Rahul','Delhi'),
(6,'Meena','Pune'),
(7,'Kiran','Chennai'),
(8,'Anu','Kochi');

-- %%
CREATE TABLE Orders (
    order_id INT PRIMARY KEY,
    customer_id INT,
    product VARCHAR(50),
    amount INT
);

-- %%
INSERT INTO Orders VALUES
(101,1,'Laptop',70000),
(102,1,'Mouse',800),
(103,3,'Keyboard',1500),
(104,4,'Monitor',12000),
(105,4,'Printer',9000),
(106,6,'Mobile',25000),
(107,6,'Headphones',3000);

-- %%
select *from customers;

-- %%
select *from orders;

-- %%
select *from customers c where exists (
    select 1 from orders o where c.customer_id =o.customer_id
)

-- %%
select *from customers c where not exists (
    select customer_id from orders o where c.customer_id=o.customer_id
)

-- %%
select *from customers where customer_id In(
    select customer_id from orders
)

-- %%
select *from orders 
pivot(
    sum(amount)
    for customer_id in (1,3,4,6)
    );
